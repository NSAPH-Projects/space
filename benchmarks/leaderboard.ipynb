# %%
import jsonlines
import glob
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import itertools

# show all rows and columns of dataframes
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Load Benchmark Results

# %%
algomap = {
    "spatial": "\\textsc{spatial}",
    "spatialplus": "\\textsc{spatial+}",
    "gcn": "\\textsc{gcnn}",
    "dapsm": "\\textsc{dapsm}",
    "ols": "\\textsc{ols}",
    "gmerror": "\\textsc{gmerror}",
    "s2sls-lag1": "\\textsc{s2sls-lag1}",
    "s2sls-lag2": "\\textsc{s2sls-lag2}",
    "xgboost": "\\textsc{xgboost}",
}

directory_path = "benchmarks/results"
file_list = glob.glob("**/*.jsonl", root_dir=directory_path, recursive=True)
print(f"Found {len(file_list)} files")

results = []
for file in file_list:
    with jsonlines.open(f"{directory_path}/{file}", "r") as reader:
        results.extend(list(reader))

results = pd.DataFrame(results)

results = (
    results
    .assign(confounding_erf=[x["erf"] for x in results["confounding"]])
    .assign(confounding_ate=[x["ate"] for x in results["confounding"]])
    .assign(confounding_ite=[x["ite"] for x in results["confounding"]])
    .assign(confounding_importance=[x["importance"] for x in results["confounding"]])
    .query("algo != 's2sls-lag2' and algo != 'xgboost'")
    .assign(algo=results.algo.map(algomap))
)
smooth_thrsh= results.smoothness.median()
conf_erf_thrsh = np.nanquantile(results.confounding_erf, 0.5)
conf_ate_thrsh = np.nanquantile(results.confounding_ate, 0.5)
conf_ite_thrsh = np.nanquantile(results.confounding_ite, 0.5)
conf_imp_thrsh = np.nanquantile(results.confounding_importance, 0.5) 
results = (
    results
    .assign(smooth_level=["high" if x > smooth_thrsh else "low" for x in results["smoothness"]])
    .assign(conf_ate_level=["high" if x > conf_ate_thrsh else "low" for x in results["confounding_ate"]])
    .assign(conf_erf_level=["high" if x > conf_erf_thrsh else "low" for x in results["confounding_erf"]])
    .assign(conf_ite_level=["high" if x > conf_ite_thrsh else "low" for x in results["confounding_ite"]])
    .assign(conf_imp_level=["high" if x > conf_imp_thrsh else "low" for x in results["confounding_importance"]])
)
results.head()
# Out:
# Found 92 files
#         ate       erf       ite                          env  dataset_id  \
# 0  0.409233  0.204616  0.383995  county_dmgrcs_election_disc           0
# 1  0.407160  0.203580  0.382902  county_dmgrcs_election_disc           1
# 2  0.406663  0.203332  0.382641  county_dmgrcs_election_disc           2
# 3  0.409570  0.204785  0.384173  county_dmgrcs_election_disc           3
# 4  0.409370  0.204685  0.384067  county_dmgrcs_election_disc           4
#
#              algo  smoothness  \
# 0  \textsc{dapsm}    0.925588
# 1  \textsc{dapsm}    0.760690
# 2  \textsc{dapsm}    0.955891
# 3  \textsc{dapsm}    0.884109
# 4  \textsc{dapsm}    0.307451
#
#                                          confounding        timestamp  binary  \
# 0  {'erf': 0.037487830966711044, 'ate': 0.0223152...  20230827-171502    True
# 1  {'erf': 0.03191845864057541, 'ate': 0.00084824...  20230827-171502    True
# 2  {'erf': 0.05424032360315323, 'ate': 0.04438314...  20230827-171502    True
# 3  {'erf': 0.01251188013702631, 'ate': 0.02270138...  20230827-171502    True
# 4  {'erf': 0.013948217034339905, 'ate': 0.0032325...  20230827-171502    True
#
#    confounding_erf  confounding_ate  confounding_ite  confounding_importance  \
# 0         0.037488         0.022315         0.129298                0.041234
# 1         0.031918         0.000848         0.123132                0.015545
# 2         0.054240         0.044383         0.172948                0.029017
# 3         0.012512         0.022701         0.116315                0.026945
# 4         0.013948         0.003233         0.097092                0.003454
#
#   smooth_level conf_ate_level conf_erf_level conf_ite_level conf_imp_level
# 0         high            low           high            low           high
# 1         high            low            low            low            low
# 2         high           high           high           high           high
# 3         high            low            low            low            low
# 4          low            low            low            low            low

# %%
# visualize smoothness and confounding distrib
sns.set_theme(style="whitegrid")
fig, ax = plt.subplots(1, 5, figsize=(11, 2))
sns.histplot(results["smoothness"], bins=20, ax=ax[0], kde=True); ax[0].set_xlabel("Smoothness");
ax[0].axvline(smooth_thrsh, color="red")
sns.histplot(results["confounding_ate"], ax=ax[1], bins=20, kde=True); ax[1].set_xlabel("ATE")
ax[1].axvline(conf_ate_thrsh, color="red")
sns.histplot(results["confounding_erf"], ax=ax[2], bins=20, kde=True); ax[2].set_xlabel("ERF")
ax[2].axvline(conf_erf_thrsh, color="red")
sns.histplot(results["confounding_ite"], ax=ax[3], bins=20, kde=True); ax[3].set_xlabel("ITE")
ax[3].axvline(conf_ite_thrsh, color="red")
sns.histplot(results["confounding_importance"], ax=ax[4], bins=20, kde=True); ax[4].set_xlabel("FeatImp")
ax[4].axvline(conf_imp_thrsh, color="red")
plt.suptitle("Distribution of smoothness and confounding scores")
# Out:
# Text(0.5, 0.98, 'Distribution of smoothness and confounding scores')

# %% [markdown]
# ## Paper Table

# %%
def bold_best(x):
    cols = x.columns[-2:]
    for col in cols:
        v = x[col]
        i = np.argmin(v.values)
        x[col].iloc[i] = "\\bf " + v.iloc[i]
    return x


def pm(x):
    m = np.nanmean(x)
    n = np.sum(~np.isnan(x))
    ci = np.nanstd(x) / np.sqrt(n) * 1.96
    return f"{m:.2f} ± " + "{\\small " + f"{ci:.2f}" + "}"


binary_total = (
    results[results.binary]
    .groupby(["smooth_level", "conf_erf_level", "algo"])
    .agg(bin_ate=("ate", pm), bin_ite=("ite", pm))
    .fillna("n/a")
    .rename_axis(index=["Smoothness", "Confounding", "Method"])
    .reset_index()
    .groupby(["Smoothness", "Confounding"], group_keys=False)
    .apply(bold_best)
    .set_index(["Smoothness", "Confounding", "Method"])
)

cont_total = (
    results[~results.binary]
    .groupby(["smooth_level", "conf_erf_level", "algo"])
    .agg(cont_erf=("erf", pm), cont_ite=("ite", pm))
    .fillna("n/a")
    .rename_axis(index=["Smoothness", "Confounding", "Method"])
    .reset_index()
    .groupby(["Smoothness", "Confounding"], group_keys=False)
    .apply(bold_best)
    .set_index(["Smoothness", "Confounding", "Method"])
)

# # outer join
fin = pd.merge(binary_total, cont_total, how="outer", left_index=True, right_index=True)
fin.fillna("n/a", inplace=True)
fin.columns = pd.MultiIndex.from_tuples(
    [
        ("\\textsc{binary}", "\\textsc{ate}"),
        ("\\textsc{binary}", "\\textsc{ite}"),
        ("\\textsc{continuous}", "\\textsc{erf}"),
        ("\\textsc{continuous}", "\\textsc{ite}"),
    ]
)
fin
# Out:
#                                                      \textsc{binary}  \
#                                                         \textsc{ate}
# Smoothness Confounding Method
# high       high        \textsc{dapsm}           0.29 ± {\small 0.20}
#                        \textsc{gcnn}            0.16 ± {\small 0.07}
#                        \textsc{gmerror}         0.07 ± {\small 0.04}
#                        \textsc{ols}             0.08 ± {\small 0.03}
#                        \textsc{s2sls-lag1}      0.11 ± {\small 0.06}
#                        \textsc{spatial+}    \bf 0.03 ± {\small 0.03}
#                        \textsc{spatial}         0.05 ± {\small 0.03}
#            low         \textsc{dapsm}           0.39 ± {\small 0.16}
#                        \textsc{gcnn}            0.14 ± {\small 0.05}
#                        \textsc{gmerror}         0.05 ± {\small 0.02}
#                        \textsc{ols}             0.04 ± {\small 0.02}
#                        \textsc{s2sls-lag1}      0.04 ± {\small 0.02}
#                        \textsc{spatial+}    \bf 0.03 ± {\small 0.01}
#                        \textsc{spatial}         0.04 ± {\small 0.01}
# low        high        \textsc{dapsm}           0.18 ± {\small 0.11}
#                        \textsc{gcnn}            0.15 ± {\small 0.07}
#                        \textsc{gmerror}         0.09 ± {\small 0.02}
#                        \textsc{ols}             0.09 ± {\small 0.02}
#                        \textsc{s2sls-lag1}      0.09 ± {\small 0.01}
#                        \textsc{spatial+}    \bf 0.05 ± {\small 0.03}
#                        \textsc{spatial}         0.06 ± {\small 0.03}
#            low         \textsc{dapsm}           0.53 ± {\small 0.15}
#                        \textsc{gcnn}            0.17 ± {\small 0.04}
#                        \textsc{gmerror}         0.06 ± {\small 0.02}
#                        \textsc{ols}             0.07 ± {\small 0.02}
#                        \textsc{s2sls-lag1}      0.08 ± {\small 0.05}
#                        \textsc{spatial+}    \bf 0.03 ± {\small 0.01}
#                        \textsc{spatial}         0.05 ± {\small 0.02}
#
#                                                                       \
#                                                         \textsc{ite}
# Smoothness Confounding Method
# high       high        \textsc{dapsm}           0.25 ± {\small 0.15}
#                        \textsc{gcnn}            0.25 ± {\small 0.08}
#                        \textsc{gmerror}         0.14 ± {\small 0.05}
#                        \textsc{ols}             0.14 ± {\small 0.06}
#                        \textsc{s2sls-lag1}      0.15 ± {\small 0.07}
#                        \textsc{spatial+}    \bf 0.13 ± {\small 0.05}
#                        \textsc{spatial}         0.13 ± {\small 0.06}
#            low         \textsc{dapsm}           0.37 ± {\small 0.09}
#                        \textsc{gcnn}            0.28 ± {\small 0.04}
#                        \textsc{gmerror}     \bf 0.18 ± {\small 0.04}
#                        \textsc{ols}             0.18 ± {\small 0.04}
#                        \textsc{s2sls-lag1}      0.18 ± {\small 0.04}
#                        \textsc{spatial+}        0.18 ± {\small 0.04}
#                        \textsc{spatial}         0.18 ± {\small 0.04}
# low        high        \textsc{dapsm}           0.19 ± {\small 0.10}
#                        \textsc{gcnn}            0.19 ± {\small 0.08}
#                        \textsc{gmerror}         0.16 ± {\small 0.06}
#                        \textsc{ols}             0.16 ± {\small 0.06}
#                        \textsc{s2sls-lag1}      0.16 ± {\small 0.06}
#                        \textsc{spatial+}    \bf 0.15 ± {\small 0.06}
#                        \textsc{spatial}         0.15 ± {\small 0.06}
#            low         \textsc{dapsm}           0.45 ± {\small 0.08}
#                        \textsc{gcnn}            0.34 ± {\small 0.03}
#                        \textsc{gmerror}     \bf 0.18 ± {\small 0.04}
#                        \textsc{ols}             0.18 ± {\small 0.04}
#                        \textsc{s2sls-lag1}      0.19 ± {\small 0.05}
#                        \textsc{spatial+}        0.18 ± {\small 0.04}
#                        \textsc{spatial}         0.18 ± {\small 0.04}
#
#                                                  \textsc{continuous}  \
#                                                         \textsc{erf}
# Smoothness Confounding Method
# high       high        \textsc{dapsm}                            n/a
#                        \textsc{gcnn}            0.50 ± {\small 0.15}
#                        \textsc{gmerror}     \bf 0.26 ± {\small 0.07}
#                        \textsc{ols}             0.26 ± {\small 0.07}
#                        \textsc{s2sls-lag1}      0.26 ± {\small 0.07}
#                        \textsc{spatial+}        0.42 ± {\small 0.13}
#                        \textsc{spatial}         0.26 ± {\small 0.08}
#            low         \textsc{dapsm}                            n/a
#                        \textsc{gcnn}            0.43 ± {\small 0.11}
#                        \textsc{gmerror}         0.37 ± {\small 0.19}
#                        \textsc{ols}         \bf 0.36 ± {\small 0.18}
#                        \textsc{s2sls-lag1}      0.86 ± {\small 1.01}
#                        \textsc{spatial+}        0.41 ± {\small 0.19}
#                        \textsc{spatial}         0.37 ± {\small 0.19}
# low        high        \textsc{dapsm}                            n/a
#                        \textsc{gcnn}        \bf 0.30 ± {\small 0.08}
#                        \textsc{gmerror}         0.31 ± {\small 0.07}
#                        \textsc{ols}             0.31 ± {\small 0.07}
#                        \textsc{s2sls-lag1}      0.31 ± {\small 0.07}
#                        \textsc{spatial+}        0.47 ± {\small 0.12}
#                        \textsc{spatial}         0.31 ± {\small 0.07}
#            low         \textsc{dapsm}                            n/a
#                        \textsc{gcnn}            0.36 ± {\small 0.09}
#                        \textsc{gmerror}     \bf 0.32 ± {\small 0.19}
#                        \textsc{ols}             0.33 ± {\small 0.19}
#                        \textsc{s2sls-lag1}      0.70 ± {\small 0.57}
#                        \textsc{spatial+}        0.35 ± {\small 0.19}
#                        \textsc{spatial}         0.34 ± {\small 0.21}
#
#
#                                                         \textsc{ite}
# Smoothness Confounding Method
# high       high        \textsc{dapsm}                            n/a
#                        \textsc{gcnn}            0.72 ± {\small 0.16}
#                        \textsc{gmerror}         0.45 ± {\small 0.11}
#                        \textsc{ols}         \bf 0.44 ± {\small 0.11}
#                        \textsc{s2sls-lag1}      0.45 ± {\small 0.11}
#                        \textsc{spatial+}        0.56 ± {\small 0.14}
#                        \textsc{spatial}         0.44 ± {\small 0.11}
#            low         \textsc{dapsm}                            n/a
#                        \textsc{gcnn}            0.58 ± {\small 0.13}
#                        \textsc{gmerror}         0.43 ± {\small 0.19}
#                        \textsc{ols}         \bf 0.41 ± {\small 0.18}
#                        \textsc{s2sls-lag1}      0.94 ± {\small 1.06}
#                        \textsc{spatial+}        0.47 ± {\small 0.19}
#                        \textsc{spatial}         0.42 ± {\small 0.19}
# low        high        \textsc{dapsm}                            n/a
#                        \textsc{gcnn}            0.57 ± {\small 0.07}
#                        \textsc{gmerror}         0.48 ± {\small 0.10}
#                        \textsc{ols}         \bf 0.47 ± {\small 0.10}
#                        \textsc{s2sls-lag1}      0.48 ± {\small 0.10}
#                        \textsc{spatial+}        0.60 ± {\small 0.13}
#                        \textsc{spatial}         0.48 ± {\small 0.10}
#            low         \textsc{dapsm}                            n/a
#                        \textsc{gcnn}            0.50 ± {\small 0.09}
#                        \textsc{gmerror}     \bf 0.37 ± {\small 0.19}
#                        \textsc{ols}             0.38 ± {\small 0.19}
#                        \textsc{s2sls-lag1}      0.77 ± {\small 0.59}
#                        \textsc{spatial+}        0.40 ± {\small 0.19}
#                        \textsc{spatial}         0.39 ± {\small 0.20}

# %%
os.makedirs("benchmarks/tex", exist_ok=True)
fin.to_latex("benchmarks/tex/leaderboard.tex", index=True, escape=False)

# prepend begin document use package booktabs etc to the above latex
with open("benchmarks/tex/template.tex", "r") as f:
    template = f.read()

with open("benchmarks/tex/leaderboard.tex", "r") as f:
    table = f.read()

with open("benchmarks/tex/leaderboard.tex", "w") as f:
    f.write(template.replace("<table>", table))

# compile latex to pdf
import subprocess
subprocess.run(
    [
        "latexmk",
        "-pdf",
        "-jobname=benchmarks/tex/leaderboard",
        "benchmarks/tex/leaderboard.tex",
    ]
)

# remove .aux, .fdb_latexmk, .fls, .log files from benchmarks/tex
for ext in ["aux", "fdb_latexmk", "fls", "log", "gz"]:
    for f in glob.glob(f"benchmarks/tex/*.{ext}"):
        os.remove(f)
# Out:
# Rc files read:
#   NONE
# Latexmk: This is Latexmk, John Collins, 17 Mar. 2022. Version 4.77, version: 4.77.
# Latexmk: applying rule 'pdflatex'...
# Rule 'pdflatex': File changes, etc:
#    Changed files, or newly in use since previous run(s):
#   benchmarks/tex/leaderboard.tex
# Rule 'pdflatex': The following rules & subrules became out-of-date:
#   pdflatex
# ------------
# Run number 1 of rule 'pdflatex'
# ------------
# ------------
# Running 'pdflatex  -recorder --jobname="benchmarks/tex/leaderboard"  "benchmarks/tex/leaderboard.tex"'
# ------------
# This is pdfTeX, Version 3.141592653-2.6-1.40.24 (TeX Live 2022/Homebrew) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./benchmarks/tex/leaderboard.tex
# LaTeX2e <2021-11-15> patch level 1
# L3 programming layer <2022-02-24>
# (/opt/homebrew/Cellar/texlive/20220321_3/share/texmf-dist/tex/latex/base/articl
# e.cls
# Document Class: article 2021/10/04 v1.4n Standard LaTeX document class
#
# (/opt/homebrew/Cellar/texlive/20220321_3/share/texmf-dist/tex/latex/base/size10
# .clo))
# (/opt/homebrew/Cellar/texlive/20220321_3/share/texmf-dist/tex/latex/booktabs/bo
# oktabs.sty)
# (/opt/homebrew/Cellar/texlive/20220321_3/share/texmf-dist/tex/latex/multirow/mu
# ltirow.sty)
# (/opt/homebrew/Cellar/texlive/20220321_3/share/texmf-dist/tex/latex/geometry/ge
# ometry.sty
# (/opt/homebrew/Cellar/texlive/20220321_3/share/texmf-dist/tex/latex/graphics/ke
# yval.sty)
# (/opt/homebrew/Cellar/texlive/20220321_3/share/texmf-dist/tex/generic/iftex/ifv
# tex.sty
# (/opt/homebrew/Cellar/texlive/20220321_3/share/texmf-dist/tex/generic/iftex/ift
# ex.sty)))
# (/opt/homebrew/Cellar/texlive/20220321_3/share/texmf-dist/tex/latex/l3backend/l
# 3backend-pdftex.def) (./benchmarks/tex/leaderboard.aux)
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# [1{/opt/homebrew/Cellar/texlive/20220321_3/share/texmf-dist/fonts/map/pdftex/up
# dmap/pdftex.map}] (./benchmarks/tex/leaderboard.aux) ){/opt/homebrew/Cellar/tex
# live/20220321_3/share/texmf-dist/fonts/enc/dvips/cm-super/cm-super-ts1.enc}</op
# t/homebrew/Cellar/texlive/20220321_3/share/texmf-dist/fonts/type1/public/amsfon
# ts/cm/cmbx10.pfb></opt/homebrew/Cellar/texlive/20220321_3/share/texmf-dist/font
# s/type1/public/amsfonts/cm/cmbx9.pfb></opt/homebrew/Cellar/texlive/20220321_3/s
# hare/texmf-dist/fonts/type1/public/amsfonts/cm/cmcsc10.pfb></opt/homebrew/Cella
# r/texlive/20220321_3/share/texmf-dist/fonts/type1/public/amsfonts/cm/cmr10.pfb>
# </opt/homebrew/Cellar/texlive/20220321_3/share/texmf-dist/fonts/type1/public/am
# sfonts/cm/cmr9.pfb></opt/homebrew/Cellar/texlive/20220321_3/share/texmf-dist/fo
# nts/type1/public/cm-super/sfbx1000.pfb></opt/homebrew/Cellar/texlive/20220321_3
# /share/texmf-dist/fonts/type1/public/cm-super/sfrm1000.pfb>
# Output written on benchmarks/tex/leaderboard.pdf (1 page, 83054 bytes).
# Transcript written on benchmarks/tex/leaderboard.log.
# Latexmk: Getting log file 'benchmarks/tex/leaderboard.log'
# Latexmk: Examining 'benchmarks/tex/leaderboard.fls'
# Latexmk: Examining 'benchmarks/tex/leaderboard.log'
# Latexmk: Log file says output to 'benchmarks/tex/leaderboard.pdf'
# Latexmk: All targets (benchmarks/tex/leaderboard.pdf) are up-to-date

# %% [markdown]
# ## Visual Comparisons Per Environment (ERF)

# %%
sns.set_theme(style="whitegrid")

plot_data = (
    results
    .assign(algo=lambda x: x.algo.str.replace("\\textsc{", "").str.replace("}", ""))
    .melt(
        id_vars=["env", "algo"],
        value_vars=["erf", "ite"],
        var_name="estimand",
        value_name="Causal estimate error (ERF)",
    )
    .query("estimand == 'erf'")
)
algo_names = sorted(plot_data.algo.unique())


g = sns.FacetGrid(
    plot_data,
    col="env",
    col_wrap=4,
    # hue="algo",
    sharex=False,
    sharey=False,
    height=2.8,
    aspect=0.9,
    # margin_titles=True,
)
sns.set(font_scale=1.0)

palette = dict(zip(algo_names, sns.color_palette("tab10", n_colors=len(algo_names))))


# # make a barplot with the ci as error bar.
g.map_dataframe(
    sns.barplot,
    x="algo",
    y="Causal estimate error (ERF)",
    hue="algo",
    dodge=False,
    palette=palette,
    order=algo_names,
)

# Now modify the titles
for ax in g.axes.flat:
    title = ax.get_title()
    new_title = title.replace("env = ", "")  # Remove the "task=" portion
    ax.set_title(new_title)
    # make x axis font smaller
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, fontsize=12)
    # make y ticks smaller
    ax.set_xlabel("")
    ax.tick_params(axis='y', labelsize='small')

g.fig.subplots_adjust(hspace=0.5, wspace=0.25)

plt.savefig("benchmarks/figures/results_by_env.pdf", bbox_inches="tight")
# Out:
# /Users/mag7273/mambaforge/envs/benchmarks/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Visual Comparisons Per Environment (ERF)

# %%
sns.set_theme(style="whitegrid")

plot_data = (
    results
    .assign(algo=lambda x: x.algo.str.replace("\\textsc{", "").str.replace("}", ""))
    .melt(
        id_vars=["env", "algo"],
        value_vars=["erf", "ite"],
        var_name="estimand",
        value_name="Causal estimate error (ITE)",
    )
    .query("estimand == 'ite'")
)
algo_names = sorted(plot_data.algo.unique())

g = sns.FacetGrid(
    plot_data,
    col="env",
    col_wrap=4,
    sharex=False,
    sharey=False,
    height=2.8,
    aspect=0.9,
)
sns.set(font_scale=1.0)

palette = dict(zip(algo_names, sns.color_palette("tab10", n_colors=len(algo_names))))


g.map_dataframe(
    sns.barplot,
    x="algo",
    y="Causal estimate error (ITE)",
    hue="algo",
    palette=palette,
    dodge=False,
    order=algo_names,
)

# Now modify the titles
for ax in g.axes.flat:
    title = ax.get_title()
    new_title = title.replace("env = ", "")  
    ax.set_title(new_title)
    # make x axis font smaller
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, fontsize=12)
    # make y ticks smaller
    ax.set_xlabel("")
    ax.tick_params(axis='y', labelsize='small')

# legend = g.add_legend(bbox_to_anchor=(0.5, 1.05), ncol=8, fontsize=10)
g.fig.subplots_adjust(hspace=0.5, wspace=0.25)
# Out:
# /Users/mag7273/mambaforge/envs/benchmarks/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Visual Comparisons per Confounding Score and Smoothness Level

# %%
#white grid and pastel palette
sns.set_theme(style="whitegrid", palette="pastel")

plot_data = (
    results
    .assign(algo=lambda x: x.algo.str.replace("\\textsc{", "").str.replace("}", ""))
    .melt(
        id_vars=["smooth_level", "conf_erf_level", "env", "algo", "binary"],
        value_vars=["erf", "ite"],
        var_name="estimand",
        value_name="Causal estimate error",
    )
    .assign(estimand=lambda x: x.estimand.str.upper())
    # map binary to binary and cont
    .assign(binary=lambda x: x.binary.map({True: "binary", False: "continuous"}))
    # captitalize estimand
    .assign(estimand=lambda x: x.estimand.str.upper())
    # make all combinations of binary and estimand
    .assign(task=lambda x: x.binary + " | " + x.estimand)
    # make all combs of smooth and conf
    .assign(challenge=lambda x: [f"{a} smooth. | {b} conf." for a, b in zip(x.smooth_level, x.conf_erf_level)])
)
algo_names = sorted(plot_data.algo.unique())

# margin titles on left
palette = dict(zip(algo_names, sns.color_palette("tab10", n_colors=len(algo_names))))

g = sns.FacetGrid(
    plot_data,
    col="task",
    row="challenge",
    sharex=False,
    sharey=False,
    height=3.2,
    aspect=1.0,
    # hue="algo",
)
sns.set(font_scale=0.95)

# def fixed_barplot(x, y, hue, label=None, **kwargs):
#     sns.barplot(x=x, y=y, hue=hue, labels=[label], **kwargs)


# # make a barplot with the ci as error bar.
g.map_dataframe(
    sns.barplot,
    "algo",
    y="Causal estimate error",
    capsize=.2,
    palette=palette,
    errwidth=1.5,
    width=1.0,
    dodge=False,
    order=algo_names,
)

# Now modify the titles
for ax in g.axes.flat:
    title = ax.get_title()
    new_title = title.replace("challenge = ", " ").replace("task = ", "")
    ax.set_title(new_title)
    # make x axis font smaller
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90, fontsize=12)
    # make y ticks smaller
    ax.set_xlabel("")
    ax.tick_params(axis='y', labelsize='small')

# legend = g.add_legend(bbox_to_anchor=(0.5, 1.05), ncol=8, fontsize=10)
g.fig.subplots_adjust(hspace=0.5, wspace=0.25)
plt.savefig("benchmarks/figures/results_by_task.pdf", bbox_inches="tight")
# Out:
# /Users/mag7273/mambaforge/envs/benchmarks/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Visualization of Pairwise Comparisons

# %%
analysis_data = (
    results
    .assign(algo=lambda x: x.algo.str.replace("\\textsc{", "").str.replace("}", ""))
)
analysis_data.head()
# Out:
#         ate       erf       ite                          env  dataset_id  \
# 0  0.409233  0.204616  0.383995  county_dmgrcs_election_disc           0
# 1  0.407160  0.203580  0.382902  county_dmgrcs_election_disc           1
# 2  0.406663  0.203332  0.382641  county_dmgrcs_election_disc           2
# 3  0.409570  0.204785  0.384173  county_dmgrcs_election_disc           3
# 4  0.409370  0.204685  0.384067  county_dmgrcs_election_disc           4
#
#     algo  smoothness                                        confounding  \
# 0  dapsm    0.925588  {'erf': 0.037487830966711044, 'ate': 0.0223152...
# 1  dapsm    0.760690  {'erf': 0.03191845864057541, 'ate': 0.00084824...
# 2  dapsm    0.955891  {'erf': 0.05424032360315323, 'ate': 0.04438314...
# 3  dapsm    0.884109  {'erf': 0.01251188013702631, 'ate': 0.02270138...
# 4  dapsm    0.307451  {'erf': 0.013948217034339905, 'ate': 0.0032325...
#
#          timestamp  binary  confounding_erf  confounding_ate  confounding_ite  \
# 0  20230827-171502    True         0.037488         0.022315         0.129298
# 1  20230827-171502    True         0.031918         0.000848         0.123132
# 2  20230827-171502    True         0.054240         0.044383         0.172948
# 3  20230827-171502    True         0.012512         0.022701         0.116315
# 4  20230827-171502    True         0.013948         0.003233         0.097092
#
#    confounding_importance smooth_level conf_ate_level conf_erf_level  \
# 0                0.041234         high            low           high
# 1                0.015545         high            low            low
# 2                0.029017         high           high           high
# 3                0.026945         high            low            low
# 4                0.003454          low            low            low
#
#   conf_ite_level conf_imp_level
# 0            low           high
# 1            low            low
# 2           high           high
# 3            low            low
# 4            low            low

# %%
pairs_data = []

for (algo1, algo2) in itertools.combinations(algo_names, 2):
    subset1 = analysis_data.query(f"algo == '{algo1}'")
    subset2 = analysis_data.query(f"algo == '{algo2}'")
    merged = (
        pd.merge(subset1, subset2, on=['env', 'dataset_id'], how="outer")
        .assign(Comparison=f"{algo1} - {algo2}")
        .assign(ERF=lambda x: x.erf_x - x.erf_y)
        .assign(ITE=lambda x: x.ite_x - x.ite_y)
        .melt(
            id_vars=["env", "Comparison", "dataset_id"],
            value_vars=["ERF", "ITE"],
            var_name="Estimand",
            value_name="Difference",
        )
    )
    pairs_data.append(merged)
pairs_data = pd.concat(pairs_data)
pairs_data.head()

# Create FacetGrid
sns.set_theme(style="whitegrid")
g = sns.FacetGrid(
    pairs_data[pairs_data.Estimand == "ERF"],
    col="Comparison",
    col_wrap=6,
    sharex=False,
    sharey=False,
    height=3,
)
g.map_dataframe(sns.kdeplot, x="Difference")


# Add vertical lines and ribbons for mean and confidence interval
def add_mean_and_ci(*args, **kwargs):
    data = kwargs.pop("data")
    ax = plt.gca()
    x = data.Difference.values
    mean = np.nanmean(x)
    ci = np.nanstd(x) / np.sqrt(len(x[~np.isnan(x)]))

    ax.axvline(mean, color="red", linestyle="-", label="Mean")
    ax.fill_betweenx(
        [0, ax.get_ylim()[1]],
        mean - ci,
        mean + ci,
        alpha=0.3,
        color="red",
        label="95% CI",
    )
    ax.axvline(0.0, color="black", linestyle="--", label="Zero")


g.map_dataframe(add_mean_and_ci, x="Difference")

for ax in g.axes.flat:
    ax.set_xlabel("")
    ax.set_ylabel("")
    ax.set_title(ax.get_title().replace("Comparison = ", ""))

# Create a global legend
handles, labels = ax.get_legend_handles_labels()
g.fig.legend(handles, labels, loc="upper center", ncol=3, fontsize=12)

# Adjust subplot to fit global legend on top
g.fig.subplots_adjust(top=0.95, wspace=0.1)
# Out:
# /Users/mag7273/mambaforge/envs/benchmarks/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Formal Statistical Analysis

# %% [markdown]
# An installation of R and the packages `multcomp` and `lme4` is needed for the following formal test.

# %%
# %load_ext rpy2.ipython

# %%
# %%R -i analysis_data
# library(lme4)
# library(multcomp)
#
# df = analysis_data
# df$algo <- factor(df$algo, levels=c("ols", "spatial", "spatial+", "gcnn", "dapsm", "gmerror", "s2sls-lag1", "s2sls-lag2", "xgboost"))
#
# model <- lmer(erf ~ algo + (1|env:dataset_id), data = df)
# print(summary(glht(model, linfct = mcp(algo = "Tukey"))))
# Out:
# /Users/mag7273/mambaforge/envs/benchmarks/lib/python3.10/site-packages/rpy2/robjects/pandas2ri.py:65: UserWarning: Error while trying to convert the column "confounding". Fall back to string conversion. The error is: <class 'dict'>
#   warnings.warn('Error while trying to convert '
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: lmer(formula = erf ~ algo + (1 | env:dataset_id), data = df)
#
# Linear Hypotheses:
#                              Estimate Std. Error z value Pr(>|z|)
# spatial - ols == 0          0.0006585  0.0460955   0.014    1.000
# spatial+ - ols == 0         0.0731268  0.0460955   1.586    0.685
# gcnn - ols == 0             0.0695546  0.0460955   1.509    0.734
# dapsm - ols == 0            0.1425228  0.0655814   2.173    0.304
# gmerror - ols == 0          0.0030330  0.0460955   0.066    1.000
# s2sls-lag1 - ols == 0       0.1130232  0.0460955   2.452    0.173
# spatial+ - spatial == 0     0.0724683  0.0460955   1.572    0.695
# gcnn - spatial == 0         0.0688961  0.0460955   1.495    0.743
# dapsm - spatial == 0        0.1418643  0.0655814   2.163    0.310
# gmerror - spatial == 0      0.0023745  0.0460955   0.052    1.000
# s2sls-lag1 - spatial == 0   0.1123647  0.0460955   2.438    0.179
# gcnn - spatial+ == 0       -0.0035722  0.0460955  -0.077    1.000
# dapsm - spatial+ == 0       0.0693960  0.0655814   1.058    0.938
# gmerror - spatial+ == 0    -0.0700938  0.0460955  -1.521    0.727
# s2sls-lag1 - spatial+ == 0  0.0398964  0.0460955   0.866    0.977
# dapsm - gcnn == 0           0.0729682  0.0655814   1.113    0.922
# gmerror - gcnn == 0        -0.0665216  0.0460955  -1.443    0.773
# s2sls-lag1 - gcnn == 0      0.0434686  0.0460955   0.943    0.964
# gmerror - dapsm == 0       -0.1394898  0.0655814  -2.127    0.330
# s2sls-lag1 - dapsm == 0    -0.0294996  0.0655814  -0.450    0.999
# s2sls-lag1 - gmerror == 0   0.1099902  0.0460955   2.386    0.199
# (Adjusted p values reported -- single-step method)
#  要求されたパッケージ Matrix をロード中です
#  要求されたパッケージ mvtnorm をロード中です
#  要求されたパッケージ survival をロード中です
#  要求されたパッケージ TH.data をロード中です
#  要求されたパッケージ MASS をロード中です
#
#  次のパッケージを付け加えます: ‘TH.data’
#
#  以下のオブジェクトは ‘package:MASS’ からマスクされています:
#
#     geyser
#
#  追加情報:  警告メッセージ:
#  RET$pfunction("adjusted", ...) で:  Completion with error > abseps

# %%
# %%R
# model <- lmer(ite ~  + algo + (1|env:dataset_id), data = df)
# print(summary(model))
# print(summary(glht(model, linfct = mcp(algo = "Tukey"))))
# Out:
# Linear mixed model fit by REML ['lmerMod']
# Formula: ite ~ +algo + (1 | env:dataset_id)
#    Data: df
#
# REML criterion at convergence: 924.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.2601 -0.2750 -0.0701  0.0627 20.6485
#
# Random effects:
#  Groups         Name        Variance Std.Dev.
#  env:dataset_id (Intercept) 0.07855  0.2803
#  Residual                   0.14500  0.3808
# Number of obs: 788, groups:  env:dataset_id, 124
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)    0.342472   0.042459   8.066
# algospatial    0.001543   0.048360   0.032
# algospatial+   0.055706   0.048360   1.152
# algogcnn       0.145099   0.048360   3.000
# algodapsm      0.162730   0.068816   2.365
# algogmerror    0.003165   0.048360   0.065
# algos2sls-lag1 0.118542   0.048360   2.451
#
# Correlation of Fixed Effects:
#             (Intr) algspt algsp+ alggcn algdps alggmr
# algospatial -0.569
# algospatil+ -0.569  0.500
# algogcnn    -0.569  0.500  0.500
# algodapsm   -0.400  0.351  0.351  0.351
# algogmerror -0.569  0.500  0.500  0.500  0.351
# algs2sls-l1 -0.569  0.500  0.500  0.500  0.351  0.500
#
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: lmer(formula = ite ~ +algo + (1 | env:dataset_id), data = df)
#
# Linear Hypotheses:
#                             Estimate Std. Error z value Pr(>|z|)
# spatial - ols == 0          0.001543   0.048360   0.032   1.0000
# spatial+ - ols == 0         0.055706   0.048360   1.152   0.9093
# gcnn - ols == 0             0.145099   0.048360   3.000   0.0416 *
# dapsm - ols == 0            0.162730   0.068816   2.365   0.2088
# gmerror - ols == 0          0.003165   0.048360   0.065   1.0000
# s2sls-lag1 - ols == 0       0.118542   0.048360   2.451   0.1730
# spatial+ - spatial == 0     0.054163   0.048360   1.120   0.9200
# gcnn - spatial == 0         0.143555   0.048360   2.968   0.0453 *
# dapsm - spatial == 0        0.161187   0.068816   2.342   0.2185
# gmerror - spatial == 0      0.001621   0.048360   0.034   1.0000
# s2sls-lag1 - spatial == 0   0.116999   0.048360   2.419   0.1855
# gcnn - spatial+ == 0        0.089392   0.048360   1.848   0.5080
# dapsm - spatial+ == 0       0.107024   0.068816   1.555   0.7053
# gmerror - spatial+ == 0    -0.052542   0.048360  -1.086   0.9304
# s2sls-lag1 - spatial+ == 0  0.062836   0.048360   1.299   0.8489
# dapsm - gcnn == 0           0.017632   0.068816   0.256   1.0000
# gmerror - gcnn == 0        -0.141934   0.048360  -2.935   0.0504 .
# s2sls-lag1 - gcnn == 0     -0.026556   0.048360  -0.549   0.9980
# gmerror - dapsm == 0       -0.159566   0.068816  -2.319   0.2293
# s2sls-lag1 - dapsm == 0    -0.044188   0.068816  -0.642   0.9952
# s2sls-lag1 - gmerror == 0   0.115378   0.048360   2.386   0.1994
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# (Adjusted p values reported -- single-step method)

# %%
# %%R
# model <- lm(erf ~ confounding_erf, data = df)
# print(summary(model))
#
# model <- lm(ite ~ confounding_ite, data = df)
# print(summary(model))
#
# model <- lm(erf ~ confounding_importance, data = df)
# print(summary(model))
#
# model <- lm(ite ~ confounding_importance, data = df)
# print(summary(model))
# Out:
# Call:
# lm(formula = erf ~ confounding_erf, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.2991 -0.1959 -0.1526  0.0692  9.0135
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)      0.22673    0.02159   10.50   <2e-16 ***
# confounding_erf  0.40882    0.23627    1.73    0.084 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4451 on 786 degrees of freedom
# Multiple R-squared:  0.003795,	Adjusted R-squared:  0.002527
# F-statistic: 2.994 on 1 and 786 DF,  p-value: 0.08397
#
#
# Call:
# lm(formula = ite ~ confounding_ite, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.3570 -0.2528 -0.1145  0.1253  9.3795
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)      0.30986    0.03742   8.280 5.28e-16 ***
# confounding_ite  0.44641    0.17821   2.505   0.0124 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4696 on 786 degrees of freedom
# Multiple R-squared:  0.00792,	Adjusted R-squared:  0.006658
# F-statistic: 6.275 on 1 and 786 DF,  p-value: 0.01245
#
#
# Call:
# lm(formula = erf ~ confounding_importance, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.2518 -0.2080 -0.1616  0.0875  8.9920
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)             0.25259    0.02088  12.096   <2e-16 ***
# confounding_importance -0.01306    0.34722  -0.038     0.97
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.446 on 786 degrees of freedom
# Multiple R-squared:  1.799e-06,	Adjusted R-squared:  -0.00127
# F-statistic: 0.001414 on 1 and 786 DF,  p-value: 0.97
#
#
# Call:
# lm(formula = ite ~ confounding_importance, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.3630 -0.2581 -0.1247  0.1479  9.3555
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)             0.37588    0.02206  17.042   <2e-16 ***
# confounding_importance  0.45688    0.36674   1.246    0.213
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.471 on 786 degrees of freedom
# Multiple R-squared:  0.001971,	Adjusted R-squared:  0.0007009
# F-statistic: 1.552 on 1 and 786 DF,  p-value: 0.2132

# %%
# %%R
# model <- lmer(erf ~ algo + algo * smoothness  + (1 | env), data = df)
# print(summary(model))
#
# model <- lmer(ite ~ algo + algo * smoothness  + (1 | env), data = df)
# print(summary(model))
# Out:
# Linear mixed model fit by REML ['lmerMod']
# Formula: erf ~ algo + algo * smoothness + (1 | env)
#    Data: df
#
# REML criterion at convergence: 694.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.3306 -0.2164 -0.0804  0.1074 23.0260
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  env      (Intercept) 0.07276  0.2697
#  Residual             0.12889  0.3590
# Number of obs: 788, groups:  env, 11
#
# Fixed effects:
#                            Estimate Std. Error t value
# (Intercept)                0.213296   0.107852   1.978
# algospatial               -0.001646   0.099889  -0.016
# algospatial+               0.055976   0.099889   0.560
# algogcnn                  -0.022460   0.099889  -0.225
# algodapsm                  0.209373   0.141361   1.481
# algogmerror               -0.001452   0.099889  -0.015
# algos2sls-lag1             0.086556   0.099889   0.867
# smoothness                -0.022089   0.123981  -0.178
# algospatial:smoothness     0.004536   0.174900   0.026
# algospatial+:smoothness    0.033750   0.174900   0.193
# algogcnn:smoothness        0.181074   0.174900   1.035
# algodapsm:smoothness      -0.040543   0.243017  -0.167
# algogmerror:smoothness     0.008825   0.174900   0.050
# algos2sls-lag1:smoothness  0.052084   0.174900   0.298
# Linear mixed model fit by REML ['lmerMod']
# Formula: ite ~ algo + algo * smoothness + (1 | env)
#    Data: df
#
# REML criterion at convergence: 766.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.3549 -0.2038 -0.1055  0.1209 23.1274
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  env      (Intercept) 0.0924   0.3040
#  Residual             0.1413   0.3759
# Number of obs: 788, groups:  env, 11
#
# Fixed effects:
#                            Estimate Std. Error t value
# (Intercept)                0.354067   0.117898   3.003
# algospatial                0.000122   0.104577   0.001
# algospatial+               0.034085   0.104577   0.326
# algogcnn                   0.056668   0.104577   0.542
# algodapsm                  0.233951   0.148000   1.581
# algogmerror               -0.001186   0.104577  -0.011
# algos2sls-lag1             0.090725   0.104577   0.868
# smoothness                -0.023843   0.129800  -0.184
# algospatial:smoothness     0.002797   0.183107   0.015
# algospatial+:smoothness    0.042547   0.183107   0.232
# algogcnn:smoothness        0.174021   0.183107   0.950
# algodapsm:smoothness      -0.052115   0.254423  -0.205
# algogmerror:smoothness     0.008562   0.183107   0.047
# algos2sls-lag1:smoothness  0.054742   0.183107   0.299
# Correlation matrix not shown by default, as p = 14 > 12.
# Use print(summary(model), correlation=TRUE)  or
#     vcov(summary(model))        if you need it
#
#
# Correlation matrix not shown by default, as p = 14 > 12.
# Use print(summary(model), correlation=TRUE)  or
#     vcov(summary(model))        if you need it
